# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ROOT_DIR = '/content/drive/MyDrive/LAMEJORTESISDELMUNDO/ENTRENAMIENTO_YOLOV8'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.0/883.0 kB 52.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import PIL

device = ('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# 'cuda'

# %%
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !scp -r /content/runs '/content/drive/MyDrive/TESIS/ENTRENAMIENTO_YOLOV8'

# %%
# !yolo task=detect mode=train epochs=400 data=/content/drive/MyDrive/TESIS/ENTRENAMIENTO_YOLOV8/data.yaml model=yolov8s.pt imgsz=640 batch=8
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 45.0MB/s]
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/TESIS/ENTRENAMIENTO_YOLOV8'

# %%
# !cp -r /content/runs/detect/val4 '/content/drive/MyDrive/TESIS/ENTRENAMIENTO_YOLOV8'

# %%
# !cp -r /content/runs/detect/val '/content/drive/MyDrive/TESIS/ENTRENAMIENTO_YOLOV8'

# %%
# !cp -r /content/runs/detect/predict2 '/content/drive/MyDrive/TESIS/ENTRENAMIENTO_YOLOV8'
