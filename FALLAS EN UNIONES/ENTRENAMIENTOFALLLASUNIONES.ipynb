# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 17.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import PIL

device = ('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# 'cuda'

# %%
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train epochs=400 data=/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data.yaml model=yolov8s.pt imgsz=640 batch=8 project=runs/train/train2
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 145MB/s]
# Ultralytics 8.3.24 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8'

# %%
# !scp -r /content/runs '/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8'

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/runs/train/train2/train/weights/best.pt data=/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data.yaml imgsz=640 batch=8
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/labels/valid.cache... 94 images, 0 backgrounds, 0 corrupt: 100% 94/94 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:03<00:00,  3.25it/s]
#                    all         94        172      0.711      0.814      0.758      0.473
# Speed: 1.2ms preprocess, 3.2ms inference, 0.0ms loss, 6.4ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !scp -r /content/runs/detect/val2 '/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8'

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/runs/train/train2/train/weights/best.pt source=/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/test imgsz=640
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/24 /content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/test/DATA1_FALLAUNIONES_TRAIN108.jpg: 640x640 3 Fallas en Unioness, 7.8ms
# image 2/24 /content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/test/DATA1_FALLAUNIONES_TRAIN112.jpg: 640x640 1 Fallas en Uniones, 7.7ms
# image 3/24 /content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/test/DATA1_FALLAUNIONES_TRAIN118.jpg: 640x640 1 Fallas en Uniones, 8.1ms
# image 4/24 /content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/test/DATA1_FALLAUNIONES_TRAIN3.jpg: 640x640 1 Fallas en Uniones, 7.6ms
# image 5/24 /content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/test/DATA1_FALLAUNIONES_TRAIN83.jpg: 640x640 2 Fallas en Unioness, 8.1ms
# ...

# %%
# !scp -r /content/runs/detect/predict '/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8'

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/runs/train/train2/train/weights/best.pt source=/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/valid/FALLASUNION_EXTRA3.jpg imgsz=640
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8/data/images/valid/FALLASUNION_EXTRA3.jpg: 640x640 1 Fallas en Uniones, 9.5ms
# Speed: 7.2ms preprocess, 9.5ms inference, 539.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !scp -r /content/runs/detect/predict2 '/content/drive/MyDrive/TESIS/FALLASENUNIONES_YOLOV8'
