# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 38.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import PIL

device = ('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# 'cpu'

# %%
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train epochs=400 data=/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data.yaml model=yolov8s.pt imgsz=640 batch=8 project=runs/traintuberiasincrustadas/train1
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 43.2MB/s]
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8'

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/runs/traintuberiasincrustadas/train1/train/weights/best.pt data=/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data.yaml imgsz=640 batch=8
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (AMD EPYC 7B12)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# ...
# 100% 22.2M/22.2M [00:00<00:00, 84.9MB/s]
# val: Scanning /content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data/labels/valid.cache... 167 images, 1 backgrounds, 0 corrupt: 100% 168/168 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 21/21 [00:31<00:00,  1.52s/it]
#                    all        168        172      0.949      0.965      0.976      0.684
# Speed: 0.9ms preprocess, 163.4ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !scp -r /content/runs/detect '/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8'

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/runs/traintuberiasincrustadas/train1/train/weights/best.pt source=/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data/images/test imgsz=640
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (AMD EPYC 7B12)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/43 /content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data/images/test/DATA1_TUBERIASINCRUSTADAS_TRAIN118.jpg: 640x640 1 Tubería incrustada, 182.1ms
# image 2/43 /content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data/images/test/DATA1_TUBERIASINCRUSTADAS_TRAIN13.jpg: 640x640 1 Tubería incrustada, 150.9ms
# image 3/43 /content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data/images/test/DATA1_TUBERIASINCRUSTADAS_TRAIN148.jpg: 640x640 1 Tubería incrustada, 168.2ms
# image 4/43 /content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data/images/test/DATA1_TUBERIASINCRUSTADAS_TRAIN178.jpg: 640x640 1 Tubería incrustada, 161.3ms
# image 5/43 /content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8/data/images/test/DATA1_TUBERIASINCRUSTADAS_TRAIN33.jpg: 640x640 1 Tubería incrustada, 179.1ms
# ...

# %%
# !scp -r /content/runs/detect '/content/drive/MyDrive/TESIS/TUBERIASINCRUSTADASYOLOV8'
